# %%
import socket
import threading
import time

# %%
HOST = "127.0.0.1"

# %%
PORT = 65002

# %%
N = 100

# %%
def worker(i):
    with socket.socket(socket.AF_INET,socket.SOCK_STREAM) as s:
        s.connect((HOST,PORT))
        s.sendall(f"request-{i}".encode())
        reply = s.recv(1024).decode()
        print(f"[Client {i}] {reply}")

# %%
def main():
    start = time.time()
    threads = [threading.Thread(target = worker, args = (i,)) for i in range(N)]
    for t in threads:
        t.start()
    for t in threads:
        t.join()
    elapsed = time.time()-start
    
    print(f"\nAll {N} requests completed in {elapsed:.2f} seconds")
    print("(With a threaded server this should be ~2s, not ~{}s)".format(N * 2))

# %%
if __name__ == "__main__":
    main()
# Out:
# Exception in thread Thread-68 (worker):
# Exception in thread Thread-72 (worker):
# Exception in thread Thread-73 (worker):
# Exception in thread Thread-75 (worker):
# Exception in thread Thread-70 (worker):
# Traceback (most recent call last):
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\FC\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\FC\AppData\Local\Temp\ipykernel_7292\2047548090.py", line 3, in worker
#     s.connect((HOST,PORT))
#     ~~~~~~~~~^^^^^^^^^^^^^
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Traceback (most recent call last):
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\FC\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\FC\AppData\Local\Temp\ipykernel_7292\2047548090.py", line 3, in worker
#     s.connect((HOST,PORT))
#     ~~~~~~~~~^^^^^^^^^^^^^
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Traceback (most recent call last):
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\FC\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\FC\AppData\Local\Temp\ipykernel_7292\2047548090.py", line 3, in worker
#     s.connect((HOST,PORT))
#     ~~~~~~~~~^^^^^^^^^^^^^
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Traceback (most recent call last):
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\FC\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\FC\AppData\Local\Temp\ipykernel_7292\2047548090.py", line 3, in worker
#     s.connect((HOST,PORT))
#     ~~~~~~~~~^^^^^^^^^^^^^
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Traceback (most recent call last):
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 1043, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\FC\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 772, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\FC\anaconda3\Lib\threading.py", line 994, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\FC\AppData\Local\Temp\ipykernel_7292\2047548090.py", line 3, in worker
#     s.connect((HOST,PORT))
#     ~~~~~~~~~^^^^^^^^^^^^^
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# [Client 0] [Processed 'request-0' by worker thred 2108[Client 3] [Processed 'request-3' by worker thred 3764
#
# [Client 2] [Processed 'request-2' by worker thred 13588
# [Client 4] [Processed 'request-4' by worker thred 2860
# [Client 5] [Processed 'request-5' by worker thred 15268
# [Client 6] [Processed 'request-6' by worker thred 14572
# [Client 1] [Processed 'request-1' by worker thred 11220
# [Client 7] [Processed 'request-7' by worker thred 5548
# [Client 8] [Processed 'request-8' by worker thred 11380
# [Client 9] [Processed 'request-9' by worker thred 6900
# [Client 11] [Processed 'request-11' by worker thred 13100
# [Client 12] [Processed 'request-12' by worker thred 14648
# [Client 13] [Processed 'request-13' by worker thred 10500
# [Client 16] [Processed 'request-16' by worker thred 452
# [Client 18] [Processed 'request-18' by worker thred 6072
# [Client 20] [Processed 'request-20' by worker thred 14244
# [Client 22] [Processed 'request-22' by worker thred 7800
# [Client 25] [Processed 'request-25' by worker thred 10908
# [Client 27] [Processed 'request-27' by worker thred 5536
# [Client 28] [Processed 'request-28' by worker thred 3432
# [Client 29] [Processed 'request-29' by worker thred 8332
# [Client 31] [Processed 'request-31' by worker thred 6444
# [Client 33] [Processed 'request-33' by worker thred 8816
# [Client 35] [Processed 'request-35' by worker thred 12540
# [Client 36] [Processed 'request-36' by worker thred 12416
# [Client 38] [Processed 'request-38' by worker thred 8064
# [Client 39] [Processed 'request-39' by worker thred 3292
# [Client 41] [Processed 'request-41' by worker thred 14148
# [Client 42] [Processed 'request-42' by worker thred 5248
# [Client 45] [Processed 'request-45' by worker thred 8140
# [Client 47] [Processed 'request-47' by worker thred 8360
# [Client 50] [Processed 'request-50' by worker thred 5760
# [Client 52] [Processed 'request-52' by worker thred 6776
# [Client 53] [Processed 'request-53' by worker thred 3824
# [Client 56] [Processed 'request-56' by worker thred 12528
# [Client 59] [Processed 'request-59' by worker thred 5116
# [Client 60] [Processed 'request-60' by worker thred 14092
# [Client 63] [Processed 'request-63' by worker thred 13840
