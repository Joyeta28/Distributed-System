# %%
import socket

# %%
HOST = "127.0.0.1"

# %%
PORT = 65001

# %%
def main():
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as server_socket:
        server_socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
        server_socket.bind((HOST,PORT))
        server_socket.listen(5)
        print(f"[SERVER] is listening on {HOST}:{PORT}....waiting for request")
    
        while True:
            conn,addr = server_socket.accept()
            with conn:
                print(f"[SERVER] connection from {addr}")
                request = conn.recv(1024).decode()
                print(f"[SERVER] Recieved request: {request}")
                reply = f"ECHO : {request.upper()}"
                conn.sendall(reply.encode())
                print(f"[SERVER] sent reply: {reply}\n")

# %%
if __name__ == "__main__":
    main()
# Out:
# [SERVER] is listening on 127.0.0.1:65001....waiting for request
