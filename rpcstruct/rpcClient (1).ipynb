# %%
import xmlrpc.client

# %%
HOST = "127.0.0.1"
PORT = 65001

# %%
def main():
    proxy = xmlrpc.client.ServerProxy(f"http://{HOST}:{PORT}/")
    print(proxy.add(3,5))

# %%
if __name__ == "__main__":
    main()
# Out:
# 8
